# %%
### Create an RDD

# %%
# Creating an RDD of the List  
pythonList = [2.3,3.4,4.3,2.4,2.3,4.0]
print(pythonList)
parPythonData = sc.parallelize(pythonList,2)
print(parPythonData)
parPythonData.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansigreen">&lt;command-138101493347834&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      2</span> pythonList <span class="ansiyellow">=</span> <span class="ansiyellow">[</span><span class="ansicyan">2.3</span><span class="ansiyellow">,</span><span class="ansicyan">3.4</span><span class="ansiyellow">,</span><span class="ansicyan">4.3</span><span class="ansiyellow">,</span><span class="ansicyan">2.4</span><span class="ansiyellow">,</span><span class="ansicyan">2.3</span><span class="ansiyellow">,</span><span class="ansicyan">4.0</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> print<span class="ansiyellow">(</span>pythonList<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 4</span><span class="ansiyellow"> </span>parPythonData <span class="ansiyellow">=</span> sc<span class="ansiyellow">.</span>parallelize<span class="ansiyellow">(</span>pythonList<span class="ansiyellow">,</span><span class="ansicyan">2</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> print<span class="ansiyellow">(</span>parPythonData<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      6</span> parPythonData<span class="ansiyellow">.</span>collect<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/context.py</span> in <span class="ansicyan">parallelize</span><span class="ansiblue">(self, c, numSlices)</span>
# <span class="ansigreen">    483</span>         <span class="ansiyellow">[</span><span class="ansiyellow">[</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> <span class="ansiyellow">[</span><span class="ansicyan">0</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> <span class="ansiyellow">[</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> <span class="ansiyellow">[</span><span class="ansicyan">2</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> <span class="ansiyellow">[</span><span class="ansicyan">4</span><span class="ansiyellow">]</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">    484</span>         &quot;&quot;&quot;
# <span class="ansigreen">--&gt; 485</span><span class="ansiyellow">         </span>numSlices <span class="ansiyellow">=</span> int<span class="ansiyellow">(</span>numSlices<span class="ansiyellow">)</span> <span class="ansigreen">if</span> numSlices <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span> <span class="ansigreen">else</span> self<span class="ansiyellow">.</span>defaultParallelism<span class="ansiyellow"></span>
# <span class="ansigreen">    486</span>         <span class="ansigreen">if</span> isinstance<span class="ansiyellow">(</span>c<span class="ansiyellow">,</span> xrange<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    487</span>             size <span class="ansiyellow">=</span> len<span class="ansiyellow">(</span>c<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">AttributeError</span>: &apos;list&apos; object has no attribute &apos;defaultParallelism&apos;</div>

# %%
# Getting the First Element 
parPythonData.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>2.3
# </div>

# %%
#  Getting the First Two Elements 
parPythonData.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">24</span><span class="ansired">]: </span>[2.3, 3.4]
# </div>

# %%
# Getting the Number of Partitions in the RDD 
parPythonData.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">25</span><span class="ansired">]: </span>2
# </div>
